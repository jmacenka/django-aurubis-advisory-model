# %%
# Module imports

# %%
import pandas as pd

# %%
# Variable declaration

# %%
SRC_FILE = './Celox ppm O2 [ppm].csv'

# %%
# Evaluation logic

# %%
df = pd.read_csv(SRC_FILE, sep=';', index_col=0)

# %%
df.plot()
# Out:
# <Axes: xlabel='Time to charge start [h]'>
